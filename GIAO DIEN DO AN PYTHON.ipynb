# %%
#Để chạy được code TkInter => cài phần mềm hỗ trợ Anaconda_Jupyter
#tạo cửa sổ tkinter
from tkinter import*
hoa = Tk()
hoa.title('Ngoc Dang')
hoa.geometry('300x400')
hoa['bg'] = 'light pink'
hoa.attributes('-topmost', True) # code làm cho cửa sổ luôn trên cửa sổ khác

hoa.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-2-defa9307faf8> in <module>
#       1 from tkinter import*
# ----> 2 hoa = Tk()
#       3 hoa.title('Ngoc Dang')
#       4 hoa.geometry('300x400')
#       5 hoa.attributes('-topmost', True)
#
# /usr/lib/python3.8/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2259                 baseName = baseName + ext
#    2260         interactive = 0
# -> 2261         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2262         if useTk:
#    2263             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
from tkinter import *
parent = Tk()
name = Label(parent, text = "Name").grid(row = 0, column = 0)
e1 = Entry(parent).grid(row = 0, column = 1)
password = Label(parent, text = "Password").grid(row = 1, column = 0)
e2 = Entry(parent).grid(row = 1, column = 1)
submit = Button(parent, text = "Submit").grid(row = 4, column = 0)
parent.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-2-741d61246f3b> in <module>
#       1 from tkinter import *
# ----> 2 parent = Tk()
#       3 name = Label(parent, text = "Name").grid(row = 0, column = 0)
#       4 e1 = Entry(parent).grid(row = 0, column = 1)
#       5 password = Label(parent, text = "Password").grid(row = 1, column = 0)
#
# /usr/lib/python3.8/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2259                 baseName = baseName + ext
#    2260         interactive = 0
# -> 2261         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2262         if useTk:
#    2263             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %%
#tạo label với tkinter
from tkinter import*
hoa = Tk()
hoa.title('Ngoc Dang')
hoa.geometry('300x200')
hoa.attributes('-topmost', True)
name = Label(hoa, text = 'Đồ án Python', font = ('Times New Roman', 14), bg = 'blue', fg = 'white')
name.place(x = 100, y = 30)


hoa.mainloop()

# %%
#tạo label với tkinter
from tkinter import*
x = Tk()
x.title('Ngoc Dang')
x.geometry('300x200')
x.attributes('-topmost', True)
name = Label(x, text = 'Đồ án Python', font = ('Times New Roman', 14), bg = 'blue', fg = 'white')
name.place(x = 100, y = 30)
but = Button(x, text = 'Login')
but.place(x = 250, y = 200)

hoa.mainloop()

# %%
#liên kết Label, button, entry
from tkinter import*
L = Tk()
L.title('Đồ án Python')
L.geometry('300x200')
L.attributes('-topmost', True)

name = Label(L, font = ('Arial', 10), text = "Họ và tên: ")
name.place(x=10, y=10)

entry = Entry(L, width = 20, font = ('Arial', 10))
entry.place (x=100,y=10)
entry.focus()

but = Button(L, text = 'Đăng nhập', width = 10, height = 2, bg = 'pink', 
             font = ('Arial', 12), fg = 'red', command = nhapvao)
but.place(x = 120, y = 70)


def nhapvao():
    name = Label(L, text = 'Bạn đã nhập: ' + entry.get(), 
                 font = ('Times New Roman', 14), bg = 'dark blue', fg = 'white')
    name.place(x = 60, y = 120)


L.mainloop()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Liên kết label, button, entry hoàn chỉnh
from tkinter import*
L = Tk()
L.title('Đồ án Python')
L.geometry('300x200')
L.attributes('-topmost', True)

name1 = Label(L, font = ('Arial', 10), text = "Họ và tên: ")
name1.place(x=10, y=10)

name2 = Label(L, font = ('Arial', 10), text = "Mã số SV: ")
name2.place(x=10, y=50)

entry1 = Entry(L, width = 15, font = ('Arial', 10))
entry1.place (x=100,y=10)
entry1.focus()

entry2 = Entry(L, width = 15, font = ('Arial', 10))
entry2.place (x=100,y=50)

but = Button(L, text = 'Kết quả ', width = 18, height = 1, bg = 'pink', 
             font = ('Arial', 12), fg = 'red', command = nhapvao)
but.place(x = 80, y = 90)


def nhapvao():
    a = entry1.get() + entry2.get()
    name = Label(L, text = 'Thông tin là: ' + str(a), font = ('Times New Roman', 12), bg = "blue", fg = 'white')
    name.place(x = 45, y = 130)


L.mainloop()
